# %% [markdown]
# # Smart Aliens:
# ## Using Statistical Interference to Find Exoplanets that Could Harbor Intelligent Alien Life
# ---
#
# ### by Julian Estrada & William Walker
#
# -

# %%
#### IMPORT Everything here ####
import ast
import bs4
import flask
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import requests
import scipy
import scipy.stats as st
import sqlalchemy




from bs4 import BeautifulSoup

from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Float

#from selenium import webdriver
#from splinter import Browser

# %% [markdown]
# # Part I: Using Flask

# %%
## API Flask ##

# %% [markdown]
# ## Import via loading in csv file until API works

# %%
## Read in csv file ##
exoplanet_metadata_path = "data/exoplanet-archive.csv"
exoplanet_metadata = pd.read_csv(exoplanet_metadata_path)
# Out:
# /var/folders/67/mdf062hd2fs5_bsx026c6sfc0000gn/T/ipykernel_31700/3010382786.py:3: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   exoplanet_metadata = pd.read_csv(exoplanet_metadata_path)

# %% [markdown]
# # Part II: Cleaning the Data

# %%
## Create exoplanet dataframe with columns we want ##
exoplanet_df = exoplanet_metadata[[
    "pl_name", "hostname", "disc_year", "discoverymethod", "pl_orbper", "pl_orbsmax",\
          "pl_rade", "pl_masse", "pl_bmasse", "pl_insol", "pl_eqt", "st_spectype", "st_teff",\
              "glat", "glon", "sy_dist"
]]

# %%
## Shortcut of Math Items ##
pi = np.pi

sin = np.sin
cos = np.cos
arcsin = np.arcsin
arccos = np.arccos
sqrt = np.sqrt

# %%
## Convert distance to Light-Years ##
lightyear = ((2 ** 2) * 3 * (5 ** 3) * 877 * 7789 ) / (pi * 7 * 487 * 293339)
exoplanet_df["sy_dist"] *= lightyear

## Experimental average gravity of Earth in m/s^2 ##
g_earth = 9.8203

## Insert Gravity columns ##
exoplanet_df["pl_gravitye"] = exoplanet_df["pl_masse"] / (exoplanet_df["pl_rade"] ** 2)
exoplanet_df["pl_gravity"] = round(g_earth * exoplanet_df["pl_gravitye"], 4)

## X and Y value coordinates in Light-Years ##
exoplanet_df["xVal"] = exoplanet_df["sy_dist"] * -sin( exoplanet_df["glon"] * pi / 180 )\
      * cos( exoplanet_df["glat"] * pi / 180 )
exoplanet_df["yVal"] = exoplanet_df["sy_dist"] * cos( exoplanet_df["glon"] * pi / 180 )\
      * cos( exoplanet_df["glat"] * pi / 180 )
# Out:
# /var/folders/67/mdf062hd2fs5_bsx026c6sfc0000gn/T/ipykernel_31700/767550919.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exoplanet_df["sy_dist"] *= lightyear
# /var/folders/67/mdf062hd2fs5_bsx026c6sfc0000gn/T/ipykernel_31700/767550919.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exoplanet_df["pl_gravitye"] = exoplanet_df["pl_masse"] / (exoplanet_df["pl_rade"] ** 2)
# /var/folders/67/mdf062hd2fs5_bsx026c6sfc0000gn/T/ipykernel_31700/767550919.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exoplanet_df["pl_gravity"] = round(g_earth * exoplanet_df["pl_gravitye"], 4)
# /var/folders/67/mdf062hd2fs5_bsx026c6sfc0000gn/T/ipykernel_31700/767550919.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exoplanet_df["xVal"] = exoplanet_df["sy_dist"] * -sin( exoplanet_df["glon"] * pi / 180 )\
# /var/folders/67/mdf062hd2fs5_bsx026c6sfc0000gn/T/ipykernel_31700/767550919.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exoplanet_df["yVal"] = exoplanet_df["sy_dist"] * cos( exoplanet_df["glon"] * pi / 180 )\

# %%
## Reorder Columns ##
exoplanet_df = exoplanet_df[[
    "pl_name", "hostname", "disc_year", "discoverymethod", "pl_orbper", "pl_orbsmax",\
          "pl_rade", "pl_masse", "pl_gravitye", "pl_gravity", "pl_insol", "pl_eqt",\
              "st_spectype", "st_teff", "glat", "glon", "sy_dist", "xVal", "yVal"
]]

## Drop all rows with Null values ##
exoplanet_df = exoplanet_df.dropna()
plNum = len(exoplanet_df["pl_name"].unique())

## Drop all rows with repeated planets ##
exoplanet_df = exoplanet_df.drop_duplicates(subset=["pl_name", "pl_rade"], keep= False)

## How many Planets do we have? ##
print(f"How many unique Exoplanets have Full Data? It's {plNum}!")

exoplanet_df.head(25)
# Out:
# How many unique Exoplanets have Full Data? It's 172!
#                   pl_name           hostname  disc_year  discoverymethod  \
# 343   CoRoTID 223977153 b  CoRoTID 223977153       2017          Transit
# 472      EPIC 246851721 b     EPIC 246851721       2018          Transit
# 474      EPIC 249893012 b     EPIC 249893012       2020          Transit
# 475      EPIC 249893012 c     EPIC 249893012       2020          Transit
# 476      EPIC 249893012 d     EPIC 249893012       2020          Transit
# 481              G 9-40 b             G 9-40       2019          Transit
# 506             GJ 1214 b            GJ 1214       2009          Transit
# 600              GJ 357 b             GJ 357       2019          Transit
# 604              GJ 367 b             GJ 367       2021          Transit
# 612             GJ 3929 b            GJ 3929       2022          Transit
# 661              GJ 486 b             GJ 486       2021  Radial Velocity
# 778             GJ 9827 b            GJ 9827       2017          Transit
# 780             GJ 9827 b            GJ 9827       2017          Transit
# 781             GJ 9827 c            GJ 9827       2017          Transit
# 785             GJ 9827 c            GJ 9827       2017          Transit
# 787             GJ 9827 d            GJ 9827       2017          Transit
# 789             GJ 9827 d            GJ 9827       2017          Transit
# 792               GPX-1 b              GPX-1       2021          Transit
# 1255           HAT-P-68 b           HAT-P-68       2020          Transit
# 1337            HATS-17 b            HATS-17       2016          Transit
# 1341            HATS-18 b            HATS-18       2016          Transit
# 1415            HATS-36 b            HATS-36       2018          Transit
# 1723          HD 110113 b          HD 110113       2021          Transit
# 2397          HD 191939 b          HD 191939       2020          Transit
# 2400          HD 191939 c          HD 191939       2020          Transit
#
#       pl_orbper  pl_orbsmax  pl_rade    pl_masse  pl_gravitye  pl_gravity  \
# 343    6.718370     0.07100    6.389    47.67450     1.167940     11.4695
# 472    6.180235     0.07229   11.781   953.49000     6.869922     67.4647
# 474    3.595100     0.04700    1.950     8.75000     2.301118     22.5977
# 475   15.624000     0.13000    3.670    14.67000     1.089176     10.6960
# 476   35.747000     0.22000    3.940    10.18000     0.655776      6.4399
# 481    5.746007     0.03850    2.025    11.70000     2.853224     28.0195
# 506    1.580404     0.01490    2.742     8.17000     1.086644     10.6712
# 600    3.930720     0.03500    1.217     1.84000     1.242329     12.2000
# 2397    100.00   880.0        G9 V   5348.0  17.72195   99.98716   174.848846
# 2400     21.00   600.0        G9 V   5348.0  17.72195   99.98716   174.848846
#
#              xVal         yVal
# 343    749.075238 -1724.205756
# 472    144.018068 -1177.126315
# 474    222.423647   836.542327
# 475    222.423647   836.542327
# 476    222.423647   836.542327
# 481     31.948946   -65.316615
# 506    -19.294982    39.278025
# 600     27.415639    -7.919115
# 604     30.526867     1.195791
# 612    -27.922271    18.366496
# 661      6.816993     3.941680
# 778    -51.833033     7.887106
# 780    -51.833033     7.887106
# 781    -51.833033     7.887106
# 785    -51.833033     7.887106
# 787    -51.833033     7.887106
# 789    -51.833033     7.887106
# 792  -1456.250456 -1555.819009
# 1255   177.780874  -576.305626
# 1337  1062.842177   676.162252
# 1341  1698.211490   413.557964
# 1415  -705.153707  2567.609668
# 1723   282.406464   168.362336
# 2397  -164.027571   -28.884586
# 2400  -164.027571   -28.884586

# %%
## Name of File: ##
file_name = 'test'
## Upload Dataframe to csv file ##
exoplanet_df.to_csv(f"data/{file_name}.csv", sep=',', encoding='utf-8')

# %% [markdown]
# # Part III: Further manipulation

# %%
#### Get most Earth-Like planets ####

## Sort by earth radii ##
earthRade = 1
topRadii = exoplanet_df.iloc[(exoplanet_df['pl_rade'] - earthRade).abs().argsort()[:]]

## Sort by earth mass ##
earthMass = 1
topMass = exoplanet_df.iloc[(exoplanet_df['pl_masse'] - earthMass).abs().argsort()[:]]

## Sort by earth black body temp ##
earthEQT = 255
topEQT = exoplanet_df.iloc[(exoplanet_df['pl_eqt'] - earthEQT).abs().argsort()[:]]

# %%
topRadii.head(10)
# Out:
#            pl_name   hostname  disc_year discoverymethod  pl_orbper  \
# 5014      K2-415 b     K2-415       2023         Transit   4.017969
# 32310  LP 791-18 d  LP 791-18       2023         Transit   2.753436
# 2725    HD 23472 f   HD 23472       2022         Transit  12.162184
# 612      GJ 3929 b    GJ 3929       2022         Transit   2.616274
# 32264    L 98-59 b    L 98-59       2019         Transit   2.253114
# 33487    TOI-500 b    TOI-500       2022         Transit   0.548177
# 2723    HD 23472 e   HD 23472       2022         Transit   7.907540
# 600       GJ 357 b     GJ 357       2019         Transit   3.930720
# 781      GJ 9827 c    GJ 9827       2017         Transit   3.648230
# 2756   HD 260655 b  HD 260655       2022         Transit   2.769530
#
#        pl_orbsmax  pl_rade  pl_masse  pl_gravitye  pl_gravity  pl_insol  \
# 5014      0.02700    1.015      7.50     7.279963     71.4914      4.82
# 32310     0.01992    1.032      0.90     0.845051      8.2987      5.83
# 2725      0.09060    1.137      0.77     0.595621      5.8492     26.30
# 612       0.02569    1.150      1.21     0.914934      8.9849     17.50
# 32264     0.02191    0.850      0.40     0.553633      5.4368     24.70
# 33487     0.01189    1.166      1.42     1.044459     10.2569   1138.00
# 2723      0.06800    0.818      0.72     1.076034     10.5670     46.70
# 600       0.03500    1.217      1.84     1.242329     12.2000     12.60
# 781       0.04290    1.240      1.45     0.943028      9.2608     59.00
# 2756      0.02933    1.240      2.14     1.391779     13.6677     42.20
#
#        pl_eqt       st_spectype  st_teff      glat       glon     sy_dist  \
# 5014    412.0              M5 V   3173.0  35.80871  217.79828   71.161451
# 32310   396.0  M(6.1 +/- 0.7) V   2960.0  39.10605  268.56582   86.407631
# 2725    630.0              K4 V   4684.0 -44.84798  277.02690  127.312207
# 612     569.0            M3.5 V   3369.0  49.59735   56.66419   51.563693
# 32264   627.0              M3 V   3415.0 -17.59330  281.81705   34.635850
# 33487  1617.0              K6 V   4440.0 -17.33308  258.09657  154.573335
# 2723    723.0              K4 V   4684.0 -44.84798  277.02690  127.312207
# 600     525.0            M2.5 V   3505.0  22.08045  253.88843   30.795065
# 781     771.0              K6 V   4219.0 -57.18299   81.34803   96.741243
# 2756    709.0              M0 V   3803.0   4.86549  195.67069   32.633576
#
#              xVal       yVal
# 5014    35.369589 -45.601026
# 32310   67.029572  -1.678179
# 2725    89.583889  11.042214
# 612    -27.922271  18.366496
# 32264   32.316073   6.761216
# 33487  144.381091 -30.434895
# 2723    89.583889  11.042214
# 600     27.415639  -7.919115
# 781    -51.833033   7.887106
# 2756     8.782825 -31.307366

# %%
topMass.head(10)
# Out:
#            pl_name   hostname  disc_year discoverymethod  pl_orbper  \
# 32310  LP 791-18 d  LP 791-18       2023         Transit   2.753436
# 612      GJ 3929 b    GJ 3929       2022         Transit   2.616274
# 2725    HD 23472 f   HD 23472       2022         Transit  12.162184
# 2723    HD 23472 e   HD 23472       2022         Transit   7.907540
# 604       GJ 367 b     GJ 367       2021         Transit   0.321923
# 33487    TOI-500 b    TOI-500       2022         Transit   0.548177
# 2721    HD 23472 d   HD 23472       2022         Transit   3.976640
# 781      GJ 9827 c    GJ 9827       2017         Transit   3.648230
# 32264    L 98-59 b    L 98-59       2019         Transit   2.253114
# 600       GJ 357 b     GJ 357       2019         Transit   3.930720
#
#        pl_orbsmax  pl_rade  pl_masse  pl_gravitye  pl_gravity  pl_insol  \
# 32310     0.01992    1.032     0.900     0.845051      8.2987      5.83
# 612       0.02569    1.150     1.210     0.914934      8.9849     17.50
# 2725      0.09060    1.137     0.770     0.595621      5.8492     26.30
# 2723      0.06800    0.818     0.720     1.076034     10.5670     46.70
# 604       0.00709    0.699     0.633     1.295536     12.7225    579.00
# 33487     0.01189    1.166     1.420     1.044459     10.2569   1138.00
# 2721      0.04298    0.750     0.550     0.977778      9.6021    117.00
# 781       0.04290    1.240     1.450     0.943028      9.2608     59.00
# 32264     0.02191    0.850     0.400     0.553633      5.4368     24.70
# 600       0.03500    1.217     1.840     1.242329     12.2000     12.60
#
#        pl_eqt       st_spectype  st_teff      glat       glon     sy_dist  \
# 32310   396.0  M(6.1 +/- 0.7) V   2960.0  39.10605  268.56582   86.407631
# 612     569.0            M3.5 V   3369.0  49.59735   56.66419   51.563693
# 2725    630.0              K4 V   4684.0 -44.84798  277.02690  127.312207
# 2723    723.0              K4 V   4684.0 -44.84798  277.02690  127.312207
#
#               xVal        yVal
# 14352 -1225.190100  391.841809
# 32313    54.672146  -51.136041
# 32281    -9.140692   -4.341379
# 33238  -118.163801  -35.576358
# 14290 -1682.302784  486.633355
# 4613     81.621202   -7.158845
# 32307    67.029572   -1.678179
# 33099   -88.105396  -23.056453
# 33018    87.923239   18.409124
# 33056   -64.059397  -36.362827

# %%
planetNameList = []
earthRankList = []


for i in range(0, len(exoplanet_df["pl_name"])):
    planetNameList.append(list(exoplanet_df["pl_name"])[i])

    ## radii arg ##
    radARG = float(list(exoplanet_df["pl_rade"])[i]) - earthRade

    ## mass arg ##
    massARG = float(list(exoplanet_df["pl_masse"])[i]) - earthMass

    ## temp arg ##
    tempARG =  ( float(list(exoplanet_df["pl_eqt"])[i]) - earthEQT) / earthEQT


    ## Average specs out ##
    earthRank = round(100 * np.e ** (-sqrt( radARG ** 2 + massARG ** 2 + tempARG ** 2 )), 3)
    earthRankList.append(earthRank)

earthRankList

earthLike_df = pd.DataFrame({
    "pl_name": planetNameList,
    "earth-like_score": earthRankList
})


earthLike_df = earthLike_df.sort_values("earth-like_score", ascending = False)

earthLike_df.head(20)
# Out:
#          pl_name  earth-like_score
# 80   LP 791-18 d            56.960
# 77     L 98-59 d            28.752
# 9      GJ 3929 b            28.419
# 58        K2-3 d            27.272
# 7       GJ 357 b            25.440
# 116   TOI-1266 c            25.424
# 32    HD 23472 f            22.430
# 75     L 98-59 b            20.505
# 76     L 98-59 c            17.680
# 57        K2-3 c            15.942
# 31    HD 23472 e            15.483
# 137    TOI-244 b            14.509
# 13     GJ 9827 c            12.408
# 33   HD 260655 b            11.911
# 16     GJ 9827 d            10.102
# 34   HD 260655 c             8.538
# 10      GJ 486 b             7.867
# 14     GJ 9827 c             7.310
# 30    HD 23472 d             7.310
# 29    HD 23472 c             6.763

# %%
exoplanet_df.loc[exoplanet_df["pl_name"] == 'LP 791-18 d', :]
# Out:
#            pl_name   hostname  disc_year discoverymethod  pl_orbper  \
# 32310  LP 791-18 d  LP 791-18       2023         Transit   2.753436
#
#        pl_orbsmax  pl_rade  pl_masse  pl_gravitye  pl_gravity  pl_insol  \
# 32310     0.01992    1.032       0.9     0.845051      8.2987      5.83
#
#        pl_eqt       st_spectype  st_teff      glat       glon    sy_dist  \
# 32310   396.0  M(6.1 +/- 0.7) V   2960.0  39.10605  268.56582  86.407631
#
#             xVal      yVal
# 32310  67.029572 -1.678179

# %%
exoplanet_df.loc[exoplanet_df["pl_name"] == 'L 98-59 d', :]
# Out:
#          pl_name hostname  disc_year discoverymethod  pl_orbper  pl_orbsmax  \
# 32273  L 98-59 d  L 98-59       2019         Transit   7.450724      0.0486
#
#        pl_rade  pl_masse  pl_gravitye  pl_gravity  pl_insol  pl_eqt  \
# 32273    1.521      1.94     0.838578      8.2351      5.01   416.0
#
#       st_spectype  st_teff     glat       glon   sy_dist       xVal      yVal
# 32273        M3 V   3415.0 -17.5933  281.81705  34.63585  32.316073  6.761216

# %%
exoplanet_df
# Out:
#                    pl_name           hostname  disc_year discoverymethod  \
# 343    CoRoTID 223977153 b  CoRoTID 223977153       2017         Transit
# 472       EPIC 246851721 b     EPIC 246851721       2018         Transit
# 474       EPIC 249893012 b     EPIC 249893012       2020         Transit
# 475       EPIC 249893012 c     EPIC 249893012       2020         Transit
# 476       EPIC 249893012 d     EPIC 249893012       2020         Transit
# ...                    ...                ...        ...             ...
# 34148         WASP-173 A b         WASP-173 A       2018         Transit
# 34229           WASP-193 b           WASP-193       2023         Transit
# 34448            WASP-44 b            WASP-44       2011         Transit
# 34951               XO-7 b               XO-7       2019         Transit
# 35040             pi Men c           HD 39091       2018         Transit
#
#        pl_orbper  pl_orbsmax  pl_rade    pl_masse  pl_gravitye  pl_gravity  \
# 343     6.718370     0.07100    6.389    47.67450     1.167940     11.4695
# 472     6.180235     0.07229   11.781   953.49000     6.869922     67.4647
# 474     3.595100     0.04700    1.950     8.75000     2.301118     22.5977
# 475    15.624000     0.13000    3.670    14.67000     1.089176     10.6960
# 476    35.747000     0.22000    3.940    10.18000     0.655776      6.4399
# ...          ...         ...      ...         ...          ...         ...
# 34148   1.386653     0.02508   14.404  1102.87010     5.315672     52.2015
# 34229   6.246334     0.06760   16.410    44.17815     0.164055      1.6111
# 34448   2.423804     0.03453   12.330   276.51210     1.818813     17.8613
# 34951   2.864142     0.04421   15.390   225.34147     0.951402      9.3430
# 35040   6.267900     0.06839    2.042     4.82000     1.155941     11.3517
#
#        pl_insol  pl_eqt st_spectype  st_teff      glat       glon  \
# 343      132.26   938.0       G0 VI   5970.0   1.86373  203.48237
# 472      642.00  1401.0        F5 V   6202.0 -12.64088  186.97531
# 474     1037.00  1616.0     G8 IV/V   5430.0  34.30816  345.11043
# 475      160.00   990.0     G8 IV/V   5430.0  34.30816  345.11043
# 476       53.00   752.0     G8 IV/V   5430.0  34.30816  345.11043
# ...         ...     ...         ...      ...       ...        ...
# 34148   1920.00  1842.0          G2   5767.0 -72.33626    3.29979
# 34229    413.00  1254.0          F9   6078.0  26.70080  275.36894
# 34448    533.00  1337.0        G8 V   5420.0 -72.63944   92.23763
# 34951   1540.00  1743.0        G0 V   6250.0  27.47379  117.58141
# 35040    309.00  1170.0        G0 V   6037.0 -29.77608  292.50808
#
#            sy_dist         xVal         yVal
# 343    1880.888384   749.075238 -1724.205756
# 472    1215.363033   144.018068 -1177.126315
# 474    1047.927395   222.423647   836.542327
# 475    1047.927395   222.423647   836.542327
# 476    1047.927395   222.423647   836.542327
# ...            ...          ...          ...
# 34148   759.879129   -13.271706   230.187923
# 34229  1180.969843  1050.408636    98.718366
# 34448  1188.879136  -354.471854   -13.850590
# 34951   763.691897  -600.561663  -313.717980
# 35040    59.589423    47.782107    19.799892
#
# [182 rows x 19 columns]

# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect("test.sqlite")

# %%
exoplanet_df.to_sql(name = "test", con = conn)
# Out:
# 182

# %% [markdown]
# # Part IV: Put forth into javascript
