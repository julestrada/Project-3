# %% [markdown]
# # Smart Aliens:
# ## Using Statistical Interference to Find Exoplanets that Could Harbor Intelligent Beings
# ---
#
# ### by Julian Estrada & William Walker
#
# -

# %%
#### IMPORT Everything here ####
import ast
import bs4
import flask
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import requests
import scipy
import scipy.stats as st
import sqlalchemy




from bs4 import BeautifulSoup

from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Float

#from selenium import webdriver
#from splinter import Browser

# %% [markdown]
# # Part I: Using Flask

# %%
## API Flask ##

# %% [markdown]
# ## Import via loading in csv file until API works

# %%
## Read in csv file ##
exoplanet_metadata_path = "../data/exoplanet-archive.csv"
exoplanet_metadata = pd.read_csv(exoplanet_metadata_path)
# Out:
# /var/folders/67/mdf062hd2fs5_bsx026c6sfc0000gn/T/ipykernel_18070/2707146230.py:3: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   exoplanet_metadata = pd.read_csv(exoplanet_metadata_path)

# %% [markdown]
# # Part II: Cleaning the Data

# %%
## Create exoplanet dataframe with columns we want ##
exoplanet_df = exoplanet_metadata[[
    "pl_name", "hostname", "disc_year", "discoverymethod", "pl_orbper", "pl_orbsmax",\
          "pl_rade", "pl_masse", "pl_bmasse", "pl_insol", "pl_eqt", "st_spectype", "st_teff",\
              "glat", "glon", "sy_dist"
]]

# %%
## Math Constants ##
e = np.e
pi = np.pi


## Math Operations ##
arccos = np.arccos
arcsin = np.arcsin
cos = np.cos
ln = np.log
sin = np.sin
sqrt = np.sqrt

# %%
## Convert distance to Light-Years ##
lightyear = ((2 ** 2) * 3 * (5 ** 3) * 877 * 7789 ) / (pi * 7 * 487 * 293339)
exoplanet_df["sy_dist"] *= lightyear

## Experimental average gravity of Earth in m/s^2 ##
g_earth = 9.8203

## Insert Gravity columns ##
exoplanet_df["pl_gravitye"] = exoplanet_df["pl_masse"] / (exoplanet_df["pl_rade"] ** 2)
exoplanet_df["pl_gravity"] = round(g_earth * exoplanet_df["pl_gravitye"], 4)

## X and Y value coordinates in Light-Years ##
exoplanet_df["xVal"] = exoplanet_df["sy_dist"] * -sin( exoplanet_df["glon"] * pi / 180 )\
      * cos( exoplanet_df["glat"] * pi / 180 )
exoplanet_df["yVal"] = exoplanet_df["sy_dist"] * cos( exoplanet_df["glon"] * pi / 180 )\
      * cos( exoplanet_df["glat"] * pi / 180 )
# Out:
# /var/folders/67/mdf062hd2fs5_bsx026c6sfc0000gn/T/ipykernel_18070/767550919.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exoplanet_df["sy_dist"] *= lightyear
# /var/folders/67/mdf062hd2fs5_bsx026c6sfc0000gn/T/ipykernel_18070/767550919.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exoplanet_df["pl_gravitye"] = exoplanet_df["pl_masse"] / (exoplanet_df["pl_rade"] ** 2)
# /var/folders/67/mdf062hd2fs5_bsx026c6sfc0000gn/T/ipykernel_18070/767550919.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exoplanet_df["pl_gravity"] = round(g_earth * exoplanet_df["pl_gravitye"], 4)
# /var/folders/67/mdf062hd2fs5_bsx026c6sfc0000gn/T/ipykernel_18070/767550919.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exoplanet_df["xVal"] = exoplanet_df["sy_dist"] * -sin( exoplanet_df["glon"] * pi / 180 )\
# /var/folders/67/mdf062hd2fs5_bsx026c6sfc0000gn/T/ipykernel_18070/767550919.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exoplanet_df["yVal"] = exoplanet_df["sy_dist"] * cos( exoplanet_df["glon"] * pi / 180 )\

# %%
## Reorder Columns ##
exoplanet_df = exoplanet_df[[
    "pl_name", "hostname", "disc_year", "discoverymethod", "pl_orbper", "pl_orbsmax",\
          "pl_rade", "pl_masse", "pl_gravity", "pl_insol", "pl_eqt",\
              "st_spectype", "st_teff", "glat", "glon", "sy_dist", "xVal", "yVal"
]]

## Drop all rows with Null values ##
exoplanet_df = exoplanet_df.dropna()

## Drop all rows with repeated planets ##
exoplanet_df = exoplanet_df.drop_duplicates(subset=["pl_name"], keep= False)

## How many Planets do we have? ##
print( f"How many unique Exoplanets have Full Data? It's { len( exoplanet_df['pl_name'].unique() ) }!" )



exoplanet_df.head(25)
# Out:
# How many unique Exoplanets have Full Data? It's 162!
#                   pl_name           hostname  disc_year  discoverymethod  \
# 343   CoRoTID 223977153 b  CoRoTID 223977153       2017          Transit
# 472      EPIC 246851721 b     EPIC 246851721       2018          Transit
# 474      EPIC 249893012 b     EPIC 249893012       2020          Transit
# 475      EPIC 249893012 c     EPIC 249893012       2020          Transit
# 476      EPIC 249893012 d     EPIC 249893012       2020          Transit
# 481              G 9-40 b             G 9-40       2019          Transit
# 506             GJ 1214 b            GJ 1214       2009          Transit
# 600              GJ 357 b             GJ 357       2019          Transit
# 604              GJ 367 b             GJ 367       2021          Transit
# 612             GJ 3929 b            GJ 3929       2022          Transit
# 661              GJ 486 b             GJ 486       2021  Radial Velocity
# 792               GPX-1 b              GPX-1       2021          Transit
# 1255           HAT-P-68 b           HAT-P-68       2020          Transit
# 1337            HATS-17 b            HATS-17       2016          Transit
# 1341            HATS-18 b            HATS-18       2016          Transit
# 1415            HATS-36 b            HATS-36       2018          Transit
# 1723          HD 110113 b          HD 110113       2021          Transit
# 2397          HD 191939 b          HD 191939       2020          Transit
# 2400          HD 191939 c          HD 191939       2020          Transit
# 2403          HD 191939 d          HD 191939       2020          Transit
# 2497          HD 207496 b          HD 207496       2023          Transit
# 2512          HD 207897 b          HD 207897       2021          Transit
# 2714           HD 23472 b           HD 23472       2019          Transit
# 2717           HD 23472 c           HD 23472       2019          Transit
# 2721           HD 23472 d           HD 23472       2022          Transit
#
#       pl_orbper  pl_orbsmax  pl_rade    pl_masse  pl_gravity  pl_insol  \
# 343    6.718370     0.07100    6.389    47.67450     11.4695    132.26
# 472    6.180235     0.07229   11.781   953.49000     67.4647    642.00
# 474    3.595100     0.04700    1.950     8.75000     22.5977   1037.00
# 475   15.624000     0.13000    3.670    14.67000     10.6960    160.00
# 476   35.747000     0.22000    3.940    10.18000      6.4399     53.00
# 481    5.746007     0.03850    2.025    11.70000     28.0195      7.20
# 506    1.580404     0.01490    2.742     8.17000     10.6712     21.00
# 600    3.930720     0.03500    1.217     1.84000     12.2000     12.60
# 604    0.321923     0.00709    0.699     0.63300     12.7225    579.00
# 506    -19.294982    39.278025
# 600     27.415639    -7.919115
# 604     30.526867     1.195791
# 612    -27.922271    18.366496
# 661      6.816993     3.941680
# 792  -1456.250456 -1555.819009
# 1255   177.780874  -576.305626
# 1337  1062.842177   676.162252
# 1341  1698.211490   413.557964
# 1415  -705.153707  2567.609668
# 1723   282.406464   168.362336
# 2397  -164.027571   -28.884586
# 2400  -164.027571   -28.884586
# 2403  -164.027571   -28.884586
# 2497    45.089418    43.207998
# 2512   -74.606101   -40.300050
# 2714    89.583889    11.042214
# 2717    89.583889    11.042214
# 2721    89.583889    11.042214

# %%
#### Get most Earth-Like planets ####
earthRankList = []

earthRade = 1
earthMass = 1
earthEQT = 255


for i in range(0, len(exoplanet_df["pl_name"])):
  

    ## radii arg ##
    radARG = float(list(exoplanet_df["pl_rade"])[i]) - earthRade

    ## mass arg ##
    massARG = float(list(exoplanet_df["pl_masse"])[i]) - earthMass

    ## temp arg ##
    tempARG =  ( float(list(exoplanet_df["pl_eqt"])[i]) - earthEQT) / earthEQT


    ## Average specs out ##
    earthRank = round(100 * np.e ** (-sqrt( radARG ** 2 + massARG ** 2 + tempARG ** 2 )/4), 3)
    earthRankList.append(earthRank)

exoplanet_df["earth-like-score"] = earthRankList


#### Habitability Score (via Big Alien Theory) ####

alienRankList = []

alien_rad = 0.8
## Rocky Planet Mass and Radius are correlated by a Lambert W Function ##
## mass * (33.0120 ** (mass ** -0.0352215) ) = (33.9270 * radius ** 3) ##
## (close to m = 0.9757 * r ** 3) ##
alien_mass = 0.4802
alienTemp = 240


for j in range(0, len(exoplanet_df["pl_name"])):

    ## radii arg ##
    radARG = float(list(exoplanet_df["pl_rade"])[j]) - alien_rad

    ## mass arg ##
    massARG = float(list(exoplanet_df["pl_masse"])[j]) - alien_mass

    ## temp arg ##
    tempARG =  ( float(list(exoplanet_df["pl_eqt"])[j]) - alienTemp) / alienTemp


    ## Average specs out ##
    lifeRank = round(100 * e ** (-sqrt( (radARG ** 2) + (massARG ** 2) + (tempARG ** 2) )/4), 3)
    alienRankList.append(lifeRank)

exoplanet_df["habitability-score"] = alienRankList

exoplanet_df.head(10)
# Out:
#                  pl_name           hostname  disc_year discoverymethod  \
# 343  CoRoTID 223977153 b  CoRoTID 223977153       2017         Transit
# 472     EPIC 246851721 b     EPIC 246851721       2018         Transit
# 474     EPIC 249893012 b     EPIC 249893012       2020         Transit
# 475     EPIC 249893012 c     EPIC 249893012       2020         Transit
# 476     EPIC 249893012 d     EPIC 249893012       2020         Transit
# 481             G 9-40 b             G 9-40       2019         Transit
# 506            GJ 1214 b            GJ 1214       2009         Transit
# 600             GJ 357 b             GJ 357       2019         Transit
# 604             GJ 367 b             GJ 367       2021         Transit
# 612            GJ 3929 b            GJ 3929       2022         Transit
#
#      pl_orbper  pl_orbsmax  pl_rade  pl_masse  pl_gravity  pl_insol  pl_eqt  \
# 343   6.718370     0.07100    6.389   47.6745     11.4695    132.26   938.0
# 472   6.180235     0.07229   11.781  953.4900     67.4647    642.00  1401.0
# 474   3.595100     0.04700    1.950    8.7500     22.5977   1037.00  1616.0
# 475  15.624000     0.13000    3.670   14.6700     10.6960    160.00   990.0
# 476  35.747000     0.22000    3.940   10.1800      6.4399     53.00   752.0
# 481   5.746007     0.03850    2.025   11.7000     28.0195      7.20   456.0
# 506   1.580404     0.01490    2.742    8.1700     10.6712     21.00   596.0
# 600   3.930720     0.03500    1.217    1.8400     12.2000     12.60   525.0
# 604   0.321923     0.00709    0.699    0.6330     12.7225    579.00  1365.0
# 612   2.616274     0.02569    1.150    1.2100      8.9849     17.50   569.0
#
#     st_spectype  st_teff      glat       glon      sy_dist        xVal  \
# 343       G0 VI   5970.0   1.86373  203.48237  1880.888384  749.075238
# 472        F5 V   6202.0 -12.64088  186.97531  1215.363033  144.018068
# 474     G8 IV/V   5430.0  34.30816  345.11043  1047.927395  222.423647
# 475     G8 IV/V   5430.0  34.30816  345.11043  1047.927395  222.423647
# 476     G8 IV/V   5430.0  34.30816  345.11043  1047.927395  222.423647
# 481      M2.5 V   3348.0  37.03563  206.06509    91.087649   31.948946
# 506        M4 V   3250.0  23.60704   26.16217    47.758100  -19.294982
# 600      M2.5 V   3505.0  22.08045  253.88843    30.795065   27.415639
# 604      M1.0 V   3522.0   5.65890  272.24323    30.699893   30.526867
# 612      M3.5 V   3369.0  49.59735   56.66419    51.563693  -27.922271
#
#             yVal  earth-like-score  habitability-score
# 343 -1724.205756             0.001               0.001
# 472 -1177.126315             0.000               0.000
# 474   836.542327             9.400               7.949
# 475   836.542327             2.856               2.466
# 476   836.542327             8.556               7.397
# 481   -65.316615             6.758               5.898
# 506    39.278025            15.340              13.303
# 600    -7.919115            71.019              62.926
# 604     1.195791            33.464              30.951
# 612    18.366496            73.013              67.167

# %%
#list out columns needed for json export
#pl_rade, Xval, Yval, habitablity-score, pl_insol, pl_eqt, pl_masse, pl_gravity, earth-like-score

# %%
selected_columns = ['pl_rade', 'xVal', 'yVal', 'habitability-score', 'pl_insol', 'pl_eqt', 'pl_masse', 'pl_gravity', 'earth-like-score']


exo_json = exoplanet_df[selected_columns].to_json(orient='records')

# %%
## Name of File: ##
file_name = 'exoplanet_df'
## Upload Dataframe to csv file ##
exoplanet_df.to_csv(f"../data/{file_name}.csv", sep=',', encoding='utf-8')

# %%
## Getting Vals into Lists for js ##
xValList = list(exoplanet_df["xVal"])
yValList = list(exoplanet_df["yVal"])

planetNameList = list(exoplanet_df["pl_name"])

for i in range(0, len(xValList)):
    xValList[i] = round(xValList[i], 3)

for j in range(0, len(yValList)):
    yValList[j] = round(yValList[j], 3)


print(xValList)
print(yValList)
print(planetNameList)
# Out:
# [749.075, 144.018, 222.424, 222.424, 222.424, 31.949, -19.295, 27.416, 30.527, -27.922, 6.817, -1456.25, 177.781, 1062.842, 1698.211, -705.154, 282.406, -164.028, -164.028, -164.028, 45.089, -74.606, 89.584, 89.584, 89.584, 89.584, 89.584, 8.783, 8.783, -251.819, 131.566, 83.561, 83.561, 59.347, 59.347, 114.638, 65.867, 222.388, 337.922, -179.195, 91.23, 91.23, -4.035, -295.366
# [47.6745, 953.49, 8.75, 14.67, 10.18, 11.7, 8.17, 1.84, 0.633, 1.21, 2.82, 6261.21962, 230.10892, 425.25654, 629.3034, 1022.14128, 4.55, 10.0, 8.0, 2.8, 6.1, 14.4, 8.32, 3.41, 0.55, 0.72, 0.77, 2.14, 3.09, 77.55052, 7.8, 10.2, 9.7, 7.8, 19.2, 42.44, 1021.18779, 21.8, 11.44182, 8.0, 21.0, 27.0, 24.5, 9.68, 15.68, 6.5, 10.7, 24.5, 5.11, 2.68, 2.2, 7.5, 215.80657, 375.0394, 1293.5681, 1074.90106, 1242.7153, 298.12454, 286.68266, 915.3504, 346.4347, 158.915, 17.0, 0.4, 2.22, 1.94, 6.65, 7.1, 0.9, 13.2, 25.3, 258.07796, 66.10864, 238.68913, 211.99155, 242.8209, 129.99182, 295.5819, 921.707, 1369.8473, 1938.763, 1373.0256, 10.15, 9.95, 1064.72516, 6.28, 15.4, 5.9, 8.1, 8.8, 5.3, 14.8, 9.5, 6.63, 13.6, 8.6, 11.8, 22.4, 3.48, 991.62463, 4.82, 7.32, 7.24, 375.0394, 4.91, 251.40353, 6.36, 26.78, 10.8, 222.47988, 46.1687, 209.7678, 4.1, 7.4, 6.37, 875.61726, 26.0, 2.68, 122.68177, 8.8, 82.63539, 222.47988, 85.3, 14.95, 16.5, 44.0, 11.0, 20.31, 38.15, 731.00534, 788.21445, 7.17, 16.42, 4096.80817, 1.42, 343.0, 170.4, 419.5335, 2.0, 5.39, 13.2, 12.6, 138.25536, 96.30201, 23.6, 5.72, 4.0, 5.3, 18.467, 4.53, 9.6, 16.137, 9.1, 98.5273, 123.9537, 40.68224, 32.10083, 1102.8701, 44.17815, 276.5121, 225.34147, 4.82]

# %% [markdown]
# # Part III: Further manipulation

# %%
starTypeList = list(exoplanet_df["st_spectype"])

for i in range(0, len(starTypeList)):
    print(starTypeList[i][0])
# Out:
# G
# F
# G
# G
# G
# M
# M
# M
# M
# M
# M
# F
# K
# G
# G
# G
# G
# G
# G
# G
# K
# K
# K
# K
# K
# K
# K
# M
# M
# F
# F
# K
# K
# G
# G
# K
# K
# G
# K
# K
# G
# G
# M
# K
# K
# K
# K
# G
# M
# M
# M
# M
# G
# F
# A
# A
# A
# G
# F
# B
# K
# G
# K
# M
# M
# M
# M
# M
# M
# M
# M
# M
# G
# G
# G
# G
# G
# K
# F
# G
# K
# G
# G
# K
# F
# M
# M
# M
# K
# K
# K
# K
# K
# K
# K
# K
# K
# G
# G
# A
# M
# M
# M
# G
# M
# G
# M
# M
# M
# F
# K
# M
# M
# M
# M
# G
# G
# M
# F
# M
# M
# M
# M
# M
# M
# M
# K
# K
# K
# F
# M
# G
# G
# F
# K
# M
# M
# G
# G
# G
# G
# G
# F
# F
# M
# G
# M
# M
# K
# K
# K
# G
# K
# G
# G
# K
# F
# G
# F
# G
# G
# G

# %%
graph = exoplanet_df.plot.scatter("st_teff", "pl_eqt", color = list(exoplanet_df["pl_orbsmax"]))

# %%
ax = plt.axes()
x = list(exoplanet_df["st_teff"])
y = list(exoplanet_df["pl_orbsmax"])

ax.scatter( x, y, c = list(exoplanet_df["pl_eqt"]) )
ax.set_title('Scatter plot')
plt.show()

# %% [markdown]
# # Part IV: Put forth into javascript
